# %%
# %%pyspark
# df = spark.read.load('abfss://files@datalake8x5c391.dfs.core.windows.net/product_data/products.csv', format='csv',
# header=True
# )
# display(df.limit(10))

# %%
df_counts = df.groupBy(df.Category).count()
display(df_counts)
